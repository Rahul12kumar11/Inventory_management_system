# %%
txt1 = { 101 : {"Name": "chips" , "Price": 10 ,"Quantity": 30 ,"Exp": "21-08-2022" ,"Type": 'Snackes' },
          102 : {"Name": "Kurkure" , "Price": 10 ,"Quantity": 30 ,"Exp": "21-08-2022" ,"Type": 'Snackes' },
          103 : {"Name": "chocalates" , "Price": 20 ,"Quantity": 30 ,"Exp": "21-08-2022" ,"Type": 'Snackes' },
          104 : {"Name": "candy" , "Price": 2 ,"Quantity": 30 ,"Exp": "21-08-2022" ,"Type": 'Snackes' },
          105 : {"Name": "Namkeens" , "Price": 10 ,"Quantity": 30 ,"Exp": "21-08-2022" ,"Type": 'Snackes' },
          106 : {"Name": "Biscuits" , "Price": 30 ,"Quantity": 30 ,"Exp": "21-08-2022" ,"Type": 'Snackes' },
          107 : {"Name": "cold_drinks" , "Price": 30 ,"Quantity": 30 ,"Exp": "21-08-2022" ,"Type": 'Snackes' },
          108 : {"Name": "Bread" , "Price": 25 ,"Quantity": 30 ,"Exp": "21-08-2022" ,"Type": 'Snackes' },
          109 : {"Name": "coffee" , "Price": 30 ,"Quantity": 30 ,"Exp": "21-08-2022" ,"Type": 'Snackes' },

          110 : {"Name": "Flour" , "Price": 30 ,"Quantity": 30 ,"Exp": "21-08-2022" ,"Type": 'Household_items' },
          111 : {"Name": "Rice" , "Price": 40 ,"Quantity": 30 ,"Exp": "21-08-2022" ,"Type": 'Household_items' },
          112 : {"Name": "Grains" , "Price": 80 ,"Quantity": 10 ,"Exp": "21-08-2022" ,"Type": 'Household_items' },
          113 : {"Name": "Oil" , "Price": 200 ,"Quantity": 10 ,"Exp": "21-08-2022" ,"Type": 'Household_items' },
          114 : {"Name": "Meggies" , "Price": 12 ,"Quantity": 30 ,"Exp": "21-08-2022" ,"Type": 'Household_items' },
          115 : {"Name": "Oats" , "Price": 80 ,"Quantity": 30 ,"Exp": "21-08-2022" ,"Type": 'Household_items' },
          116 : {"Name": "Sugar" , "Price": 30 ,"Quantity": 30 ,"Exp": "21-08-2022" ,"Type": 'Household_items' },
          117 : {"Name": "Salt" , "Price": 25 ,"Quantity": 30 ,"Exp": "21-08-2022" ,"Type": 'Household_items' },
          118 : {"Name": "Red_chilli_powder" , "Price": 20 ,"Quantity": 20 ,"Exp": "21-08-2022" ,"Type": 'Household_items' },
          119 : {"Name": "Ditergents" , "Price": 20 ,"Quantity": 20 ,"Exp": "21-08-2022" ,"Type": 'Household_items' },
          120 : {"Name": "Pickels" , "Price": 30 ,"Quantity": 40 ,"Exp": "21-08-2022" ,"Type": 'Household_items' },
          121 : {"Name": "Soup" , "Price": 20 ,"Quantity": 30 ,"Exp": "21-08-2022" ,"Type": 'Household_items' },
          122 : {"Name": "Butter" , "Price": 35 ,"Quantity": 20 ,"Exp": "21-08-2022" ,"Type": 'Household_items' },
          
          123 : {"Name": "Sauce" , "Price": 35 ,"Quantity": 20 ,"Exp": "21-08-2022" ,"Type": 'Household_items' },
          124 : {"Name": "Milk" , "Price": 30 ,"Quantity": 30 ,"Exp": "21-08-2022" ,"Type": 'Household_items' },
          125 : {"Name": "curd" , "Price": 15 ,"Quantity": 30 ,"Exp": "21-08-2022" ,"Type": 'Household_items' },
          126 : {"Name": "Ghee" , "Price": 400 ,"Quantity": 30 ,"Exp": "21-08-2022" ,"Type": 'Household_items' },
          127 : {"Name": "cashew" , "Price": 450 ,"Quantity": 30 ,"Exp": "21-08-2022" ,"Type": 'Household_items' },
          128 : {"Name": "Nuts" , "Price": 80 ,"Quantity": 5 ,"Exp": "21-08-2022" ,"Type": 'Household_items' },
          129 : {"Name": "Santizer" , "Price": 100 ,"Quantity": 30 ,"Exp": "21-08-2022" ,"Type": 'Household_items' },
          130 : {"Name": "cheese" , "Price": 80 ,"Quantity": 30 ,"Exp": "21-08-2022" ,"Type": 'Household_items' }}

# %%
import json
import time

f = open("Record.json", 'r')
txt1 = f.read()
f.close()
txt = json.loads(txt1)
def update():
  js = json.dumps(txt)
  f = open("Record.json", 'w')
  f.write(js + "\n")
  f.close()

# %%
identity = input("Are you a customer or producer? ")

if(identity == 'producer' or identity == 'Producer'):
  password = int(input("Enter the password "))
  if(password == 1234):
    status = input("You want to update the quantity or want to add new item? ")
    if(status == 'Update' or status == 'update'):
      prod_id = input("Enter the product id ")
      if(int(prod_id) > 100 and int(prod_id) < 131):
        qaun = input("Enter the quantity to want to add ")
        txt[iu_prod]['Quantity'] = txt[iu_prod]['Quantity'] + quan
        print("You add ",quan, "in ",iu_prod)
        update()
      else:
        print("The product id should be in 101 to 130 for update")
    elif(status == 'Add' or status == 'add'):
      n_prodid = input("Enter the new product id ")
      n_prodname = input("Enter the new product name ")
      n_prodprice = int(input("Enter the price of new product "))
      n_prodquan = int(input("Enter the new product quantity you want to add "))
      n_expdate = input("Enter the expiry date ")
      n_type = input("Enter the type of the product ")

      txt2 = { n_prodid :{"Name": n_prodname , "Price": n_prodprice ,"Quantity": n_prodquan ,"Exp": n_expdate ,"Type": n_type}}
      ji = json.dumps(txt2)
      fi = open("Record.json",'a')
      fi.write(ji + "\n")
      fi.close()


    else:
      print("Wrong command ")
  else:
    print("Password is wrong")


elif(identity == 'customer' or identity == 'Customer'):
  t = time.ctime()
  bill_amt = 0
  price_prod = []
  name_prod = []
  quan_prod = []
  exp_prod = []
  while(True):
    print("\n Enter the product id to purchase otherwise type 0 to finish the shoping")
    iu_prod = input("Enter the product id of the product you want ")
    if(int(iu_prod) > 100 and int(iu_prod) < 131 ):

      price_prod.append(txt[iu_prod]['Price'])
      print("The amount of this product ",txt[iu_prod]['Price'])
      
      name_prod.append(txt[iu_prod]['Name'])
      print("Name of the product ",txt[iu_prod]['Name'])

      quan = int(input("Enter the quantity of that product"))  
      if(quan > txt[iu_prod]['Quantity']):
        print("Stock is full you have only ", txt[iu_prod]['Quantity'])
      else:
        quan_prod.append(quan)
        exp_prod.append(txt[iu_prod]['Price']*quan)
        print("You are ready to purchase")
        bill_amt += txt[iu_prod]['Price']*quan
        txt[iu_prod]['Quantity'] = txt[iu_prod]['Quantity'] - quan
        update()
    elif(int(iu_prod) == 0):
      print("\n********Thanks you for visiting the store********")
      break
    else:
      print("Enter a valid product id")

else:
  print("You are not able to access anything")  
print("\n")
dec =input("Do you want to print bill just type yes or no:- ")
if(dec == 'Yes' or dec == 'yes'):
  name = input("Enter your name ")
  mob_no = int(input("Enter your mobile number "))
  print("\n *********Your Bill************")
  print("\n Your name:- ",name)
  print(" Your mobile number:- ",mob_no)
  print(" Date and time of purchase :- ",t)
  for i in range(len(name_prod)):
    print(" Product you purchase ",quan_prod[i],"", name_prod[i],"of price", price_prod[i])
    print(" Tota expence on this product ", exp_prod[i])
    
  print("Your total bill amount:- ",bill_amt)
  print("\n ****************************** ")

sale = {"Name": name , "Mobile_number": mob_no, "Time": t, "Prices of each product": price_prod ,"Name_prod of each": name_prod,"Quantity of each product": quan_prod, "Total Bill amount": str(bill_amt)}
sales = json.dumps(sale)
fd = open("Sales.json",'a')


fd.write(sales + "\n")
fd.close()
# Out:
# Are you a customer or producer? customer
#
#  Enter the product id to purchase otherwise type 0 to finish the shoping
# Enter the product id of the product you want 101
# The amount of this product  10
# Name of the product  chips
# Enter the quantity of that product10
# You are ready to purchase
#
#  Enter the product id to purchase otherwise type 0 to finish the shoping
# Enter the product id of the product you want 0
#
# ********Thanks you for visiting the store********
#
#
# Do you want to print bill just type yes or no:- yes
# Enter your name rahul
# Enter your mobile number 93883
#
#  *********Your Bill************
#
#  Your name:-  rahul
#  Your mobile number:-  93883
#  Date and time of purchase :-  Sun Sep  5 13:49:32 2021
#  Product you purchase  10  chips of price 10
#  Tota expence on this product  100
# Your total bill amount:-  100
#
#  ******************************
